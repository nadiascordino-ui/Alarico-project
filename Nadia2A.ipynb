# %% [markdown]
# <a href="https://colab.research.google.com/github/nadiascordino-ui/Alarico-project/blob/main/Nadia2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Ciao Mondo!")
x=10
# Out:
# Ciao Mondo!
